# %% [markdown]
# ## Task 2 : Calculate summary statistics.

# %%
import numpy as np
import pandas as pd

test_data = pd.read_csv('test1.csv')
train_data = pd.read_csv('train1.csv')

#load the combined dataset
combined_data = pd.concat([test_data,test_data],ignore_index=True)

#display the summary statistics
summary_stats = combined_data.describe(include='all')

print("Summary Statistis")
print(summary_stats)
# Out:
# Summary Statistis
#         PassengerId      Pclass              Name   Sex        Age  \
# count    836.000000  836.000000               836   836  664.00000
# unique          NaN         NaN               418     2        NaN
# top             NaN         NaN  Kelly, Mr. James  male        NaN
# freq            NaN         NaN                 2   532        NaN
# mean    1100.500000    2.265550               NaN   NaN   30.27259
# std      120.738094    0.841333               NaN   NaN   14.17051
# min      892.000000    1.000000               NaN   NaN    0.17000
# 25%      996.000000    1.000000               NaN   NaN   21.00000
# 50%     1100.500000    3.000000               NaN   NaN   27.00000
# 75%     1205.000000    3.000000               NaN   NaN   39.00000
# max     1309.000000    3.000000               NaN   NaN   76.00000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# ...

# %% [markdown]
# ## Task 3 : Visualization using Histogram

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset

iris_data = pd.read_csv('Iris.csv')

# List of columns to plot
columns = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# Create histograms for each column
for column in columns:
    plt.figure(figsize=(10, 6))
    plt.hist(iris_data[column], bins=10, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {column}')
    plt.xlabel(f'{column} (cm)')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
